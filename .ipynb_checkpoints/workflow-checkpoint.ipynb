# %%
import pandas as pd

data = pd.read_csv("groceriesSynthetic.tsv", sep = "\t")
df = pd.DataFrame(data)
df_original = pd.DataFrame(data)

# %%
#Checking if all the values in currency are EUR
print(df["currency"].nunique() == "EUR")
# Out:
# False

# %%
rows_with_other_currencies = df[df["currency"] != "EUR"]
print(rows_with_other_currencies)
# Out:
#          id formattedDate               merchantName  \
# 804     704    06-03-2023                        NaN
# 1362   1384    25-06-2023                        NaN
# 1806   1381    04-04-2023                        NaN
# 2530     18    16-03-2023                        NaN
# 3066   1110    01-12-2022                        NaN
# ...     ...           ...                        ...
# 96983   477    15-04-2023                        NaN
# 97047  1763    16-08-2023                        NaN
# 97815  1218    05-06-2023                        NaN
# 97902  1446    30-08-2023                        NaN
# 99425   985    15-07-2023  TALLINN anyone Debrashire
#
#                                           remittanceInfo   value currency
# 804    292384******9276 either JARVE SELVERI ISETEENI...  -10.74      USD
# 1362   (..3895) carry any WoltItaemerenkatu somebody new    -5.7      SEK
# 1806   (..6464) always sign protect everybody improve...  -22.44      SEK
# 2530   (..5274) scene prepare ICA AB/PARNU RIMI old d...  -34.07      USD
# 3066   999293******7961 traditional phone RIMI no thr...  -22.28      CAD
# ...                                                  ...     ...      ...
# 96983  023192******2771 audience near KONSUM ISETEEN ...   -1.09      GBP
# 97047  958082******5941 phone RIMI/HIIU RIMI SM ISETE...   -1.59      THB
# 97815  606650******0484 each ICA particularly RIMITAM...    -7.4      SEK
# 97902  (..3332) knowledge toward election TURU ago 1 ...  -13.48      SEK
# 99425   605783******0065 scientist face industry TALLINN   -6.49      THB
#
# [198 rows x 6 columns]

# %%
pip install CurrencyConverter
# Out:
# Requirement already satisfied: CurrencyConverter in /opt/homebrew/Cellar/jupyterlab/4.0.5_1/libexec/lib/python3.11/site-packages (0.17.13)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.5_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from currency_converter import CurrencyConverter

c = CurrencyConverter()

def currency_to_EUR(value, currency):
    if currency != "EUR":
        try:
            conversion = c.convert(value, currency, "EUR")
            return round(conversion, 2)
        except Exception as e:
            print(f"Error converting {value} {currency} to EUR: {e}")
    return value

df["value"] = df.apply(lambda row: currency_to_EUR(row["value"], row["currency"]), axis=1)

# %%
rows_with_other_currencies = df[df["currency"] != "EUR"]
print(rows_with_other_currencies)
# Out:
#          id formattedDate               merchantName  \
# 804     704    06-03-2023                        NaN
# 1362   1384    25-06-2023                        NaN
# 1806   1381    04-04-2023                        NaN
# 2530     18    16-03-2023                        NaN
# 3066   1110    01-12-2022                        NaN
# ...     ...           ...                        ...
# 96983   477    15-04-2023                        NaN
# 97047  1763    16-08-2023                        NaN
# 97815  1218    05-06-2023                        NaN
# 97902  1446    30-08-2023                        NaN
# 99425   985    15-07-2023  TALLINN anyone Debrashire
#
#                                           remittanceInfo  value currency
# 804    292384******9276 either JARVE SELVERI ISETEENI... -10.06      USD
# 1362   (..3895) carry any WoltItaemerenkatu somebody new  -0.49      SEK
# 1806   (..6464) always sign protect everybody improve...  -1.93      SEK
# 2530   (..5274) scene prepare ICA AB/PARNU RIMI old d... -31.93      USD
# 3066   999293******7961 traditional phone RIMI no thr... -15.15      CAD
# ...                                                  ...    ...      ...
# 96983  023192******2771 audience near KONSUM ISETEEN ...  -1.25      GBP
# 97047  958082******5941 phone RIMI/HIIU RIMI SM ISETE...  -0.04      THB
# 97815  606650******0484 each ICA particularly RIMITAM...  -0.63      SEK
# 97902  (..3332) knowledge toward election TURU ago 1 ...  -1.16      SEK
# 99425   605783******0065 scientist face industry TALLINN  -0.17      THB
#
# [198 rows x 6 columns]

# %%
df = df.drop(columns="currency")

# %%
def findMerchant(x):
    if isinstance(x, str):
        mer = ""
        li = x.split()
        i = 0
        while li[i].isupper():
            mer + " " + li[i]
        return mer

# %%
#finding all the merchants in the merchantName column
merchantsFromDf = df["merchantName"].apply(lambda x: x.split()[0] if isinstance(x, str) and x.split()[0].isupper() else None).dropna().unique().tolist()
print(merchantsFromDf)
# Out:
# ['MAKSIMARK', 'OU', 'RIMI', 'SELVER', 'KAUPLUS', 'KAUBAMAJA', 'KONSUM', 'AS', 'MAXIMA', 'VALD', 'POOD', 'COOP', 'TOIDUKAUBAD', 'TALLINN', 'R-KIOSK', 'PRISMA', 'ISETEEN', 'OÜ', 'A', 'STOCKMANN', 'LIDL', 'KESKUS', 'GROSSI', 'TURU', 'ICA', 'TURG', 'ISETEENINDUS', 'MAKSEKESKUS', 'PAIDE', 'MEIE', 'KURESSAARE', 'MARKET', 'TARTU', 'WWW.RIMI.EE', 'A&O', 'R', 'VIRU', 'KARDLA', 'VILJANDI', 'PARNU', 'NARVA', 'KRISTIINE', 'JOHVI', 'BOLT', 'NARVESEN', 'KOHTLA-JARVE', 'TOIT', 'POLVA', 'MAARDU', 'SIKUPILLI', 'ROCCA', 'EEDEN', 'PUHVET', 'GET', 'BLOOM', 'APOLLO']

# %%
finalMerchantList = ['MAKSIMARK', 'MAKSIMARKET','RIMI','KAUBAMAJA','SELVER', 'KONSUM','MAXIMA', 'COOP','PRISMA','STOCKMANN','LIDL', 'GROSSI', 'ICA', 'MEIE TOIDUKAUBAD',
                    'A&O', 'BOLT MARKET', 'SIKUPILLI', 'BLOOM']

# %%
def process_merchant_name_column(row):
    if pd.isnull(row["merchantName"]):
        for merchant in finalMerchantList:
            if merchant in row["remittanceInfo"].upper():
                return merchant
    else:
        list = row["merchantName"].split()
        if list[0].isupper() and list[0] in finalMerchantList:
            return list[0]
        else:
            return None

# %%
df["merchantName"] = df.apply(process_merchant_name_column, axis=1)

# %%
df = df.dropna(subset=['merchantName'])

# %%
df.head(20)
# Out:
#       id formattedDate merchantName  \
# 0   1269    24-07-2023    MAKSIMARK
# 1    319    14-06-2023         LIDL
# 3   1340    20-02-2023    MAKSIMARK
# 6    400    10-03-2023          ICA
# 7   1310    04-01-2023       MAXIMA
# 8    184    07-09-2023         RIMI
# 9   1292    09-01-2023       KONSUM
# 11   535    09-05-2023       SELVER
# 14   690    05-03-2023       KONSUM
# 17   322    01-07-2022       SELVER
# 18   525    26-08-2023         RIMI
# 21  1065    04-07-2023         RIMI
# 22  1853    02-08-2023         RIMI
# 23   348    28-04-2023       SELVER
# 26   868    17-08-2023       SELVER
# 27  1703    04-01-2023         RIMI
# 28  1781    25-03-2023    KAUBAMAJA
# 29  1817    12-07-2023         RIMI
# 31   369    11-04-2023       PRISMA
# 32   828    14-12-2022       SELVER
#
#                                        remittanceInfo   value
# 0   567176******6366 toward information MAKSIMARKE...  -13.59
# 1   157466******5153 pay LIDL own TARTU sound behi...   -0.89
# 3   24/04/1997 resource kaart...878232 VILJANDI MA...   -12.9
# 6   551163******9009 which ICA AB/TARTU LOUNAKESK ...    -5.1
# 7   Kaart:411726******8003 human seven community a...  -17.35
# 8   576266******5911 return RIMI/TATARI RIMI ISETE...   -4.28
# 9   368085******4980 difficult act KONSUM ISETEENI...       5
# 11  29/05/1985 traditional kaart...609240 huge SEL...  -21.86
# 14  146990******6058 light IHASTE KONSUM marriage ...   -1.29
# 17  (..1988) short simply stand SELVER ISETEENINSO...  -34.08
# 18  23/07/1973 half kaart...710047 RIMI/VILJANDI d...  -23.08
# 21  114088******7776 mind ICA paper RIMI H else TA...  -28.11
# 22  650344******0573 do ICA six RIMI road 64TALLINN10   -6.43
# 23  328900******4997 door together SELVER ISETEENI...   -9.07
# 26  17/04/1980 like kaart...929592 great SELVERI I...  -14.39
# 27  (..5005) myself example REMA response nation c...  -16.21
# 28  230764******1689 low KAUBAMAJA TARTU leader TA...   -6.68
# 29  01/10/2009 age kaart...223453 good RIMI painti...  -11.93
# 31  614921******6876 test Prisma Kristiine Kesku e...   -4.59
# 32  (..0107) late paper who SELVER onto employee T...  -11.56

# %%
df.shape
# Out:
# (66667, 5)

# %%
print(df[df["merchantName"]=="KURESSAARE"])
# Out:
# Empty DataFrame
# Columns: [id, formattedDate, merchantName, remittanceInfo, value]
# Index: []

# %%
# IMPORTIME re, ET SAAKS SPILTTIDA MITME CONDITIONI PÕHJAL
import re

# %%
# TEKITAME UUE TULBA NIMEGA cardNumber NING PANEME VAIKEVÄÄRTUSEKS NONE

df["cardNumber"] = None

# %%
# TEKITAME UUED TULBAD NIMEDEGA city, location NING PANEME VAIKEVÄÄRTUSTEKS NONE

df["city"] = None
df["location"] = None

# %%
# TEKITAME UUED TULBAD NIMEDEGA selfCheckout, date NING PANEME VAIKEVÄÄRTUSTEKS NONE

df["selfCheckout"] = None
df["date"] = None

# %%
# IMPORTIME datetime, ET SAAKSIME TEKITADA KUUPÄEVI

from datetime import *

# %%
#  TEKITAME LISTI EESTI LINNADEST

eestiLinnad = [
    "Võru", "Võhma", "Viljandi", "Valga", "Türi", "Tõrva", "Tartu", "Tapa", "Tamsalu", "Tallinn",
    "Suure-Jaani", "Sindi", "Sillamäe", "Saue", "Räpina", "Rapla", "Rakvere", "Püssi", "Pärnu",
    "Põlva", "Põltsamaa", "Paldiski", "Paide", "Otepää", "Narva-Jõesuu", "Narva", "Mõisaküla",
    "Mustvee", "Maardu", "Loksa", "Lihula", "Kärdla", "Kuressaare", "Kunda", "Kohtla-Järve",
    "Kiviõli", "Kilingi-Nõmme", "Keila", "Kehra", "Karksi-Nuia", "Kallaste", "Jõhvi", "Jõgeva",
    "Haapsalu", "Elva", "Antsla", "Abja-Paluoja"
]

# KUNA SAIN SELLE LISTI CHAT-ILT SIIS TEEME KÕIK UPPERCASE NING TEKITAME KA VARIANDID IAGST KUS LÕPUS ON MAA (PÕLVA -> PÕLVAMAA)

for i in range(0, len(eestiLinnad)):
    eestiLinnad[i] = eestiLinnad[i].upper()
    eestiLinnad.append(eestiLinnad[i]+"MAA")

eestiLinnad
# Out:
# ['VÕRU',
#  'VÕHMA',
#  'VILJANDI',
#  'VALGA',
#  'TÜRI',
#  'TÕRVA',
#  'TARTU',
#  'TAPA',
#  'TAMSALU',
#  'TALLINN',
#  'SUURE-JAANI',
#  'SINDI',
#  'SILLAMÄE',
#  'SAUE',
#  'RÄPINA',
#  'RAPLA',
#  'RAKVERE',
#  'PÜSSI',
#  'PÄRNU',
#  'PÕLVA',
#  'PÕLTSAMAA',
#  'PALDISKI',
#  'PAIDE',
#  'OTEPÄÄ',
#  'NARVA-JÕESUU',
#  'NARVA',
#  'MÕISAKÜLA',
#  'MUSTVEE',
#  'MAARDU',
#  'LOKSA',
#  'LIHULA',
#  'KÄRDLA',
#  'KURESSAARE',
#  'KUNDA',
#  'KOHTLA-JÄRVE',
#  'KIVIÕLI',
#  'KILINGI-NÕMME',
#  'KEILA',
#  'KEHRA',
#  'KARKSI-NUIA',
#  'KALLASTE',
#  'JÕHVI',
#  'JÕGEVA',
#  'HAAPSALU',
#  'ELVA',
#  'ANTSLA',
#  'ABJA-PALUOJA',
#  'VÕRUMAA',
#  'VÕHMAMAA',
#  'VILJANDIMAA',
#  'VALGAMAA',
#  'TÜRIMAA',
#  'TÕRVAMAA',
#  'TARTUMAA',
#  'TAPAMAA',
#  'TAMSALUMAA',
#  'TALLINNMAA',
#  'SUURE-JAANIMAA',
#  'SINDIMAA',
#  'SILLAMÄEMAA',
#  'SAUEMAA',
#  'RÄPINAMAA',
#  'RAPLAMAA',
#  'RAKVEREMAA',
#  'PÜSSIMAA',
#  'PÄRNUMAA',
#  'PÕLVAMAA',
#  'PÕLTSAMAAMAA',
#  'PALDISKIMAA',
#  'PAIDEMAA',
#  'OTEPÄÄMAA',
#  'NARVA-JÕESUUMAA',
#  'NARVAMAA',
#  'MÕISAKÜLAMAA',
#  'MUSTVEEMAA',
#  'MAARDUMAA',
#  'LOKSAMAA',
#  'LIHULAMAA',
#  'KÄRDLAMAA',
#  'KURESSAAREMAA',
#  'KUNDAMAA',
#  'KOHTLA-JÄRVEMAA',
#  'KIVIÕLIMAA',
#  'KILINGI-NÕMMEMAA',
#  'KEILAMAA',
#  'KEHRAMAA',
#  'KARKSI-NUIAMAA',
#  'KALLASTEMAA',
#  'JÕHVIMAA',
#  'JÕGEVAMAA',
#  'HAAPSALUMAA',
#  'ELVAMAA',
#  'ANTSLAMAA',
#  'ABJA-PALUOJAMAA']

# %%
# SIIT NÄHA MILLINE ON remittanceInfo SPILT

counter = 0
for index, row in df.iterrows():
    if counter <= 50:
        rowRemittanceSeperatedList = re.split(r'[ ,/]', row["remittanceInfo"])
        print(rowRemittanceSeperatedList)
        counter += 1
# Out:
# ['567176******6366', 'toward', 'information', 'MAKSIMARKET', 'outside', 'VILJANDIMAA', '']
# ['157466******5153', 'pay', 'LIDL', 'own', 'TARTU', 'sound', 'behind', 'TARTUMAA', '', 'dinner']
# ['24', '04', '1997', 'resource', 'kaart...878232', 'VILJANDI', 'MAKSIMARKET', 'VILJANDIMAA', '', 'EST', 'carry']
# ['551163******9009', 'which', 'ICA', 'AB', 'TARTU', 'LOUNAKESK', 'six', 'TARTUMAA', '', 'TAR']
# ['Kaart:411726******8003', 'human', 'seven', 'community', 'act', '-', 'Maxima', 'bank', '-', 'three', 'community']
# ['576266******5911', 'return', 'RIMI', 'TATARI', 'RIMI', 'ISETE', 'travel', 'TALLINN']
# ['368085******4980', 'difficult', 'act', 'KONSUM', 'ISETEENINDUSKESKVALJAK', '1KARDLA9']
# ['29', '05', '1985', 'traditional', 'kaart...609240', 'huge', 'SELVERI', 'ISETEENI', 'TALLINN', 'EST', 'team']
# ['146990******6058', 'light', 'IHASTE', 'KONSUM', 'marriage', 'TARTUMAA', '', 'buy']
# ['(..1988)', 'short', 'simply', 'stand', 'SELVER', 'ISETEENINSOBRA', 'wrong', 'TARTU', 'LINN', 'animal', 'thought']
# ['23', '07', '1973', 'half', 'kaart...710047', 'RIMI', 'VILJANDI', 'director', 'RI', 'VILJANDIMAA', '', 'EST', 'go']
# ['114088******7776', 'mind', 'ICA', 'paper', 'RIMI', 'H', 'else', 'TALLINN']
# ['650344******0573', 'do', 'ICA', 'six', 'RIMI', 'road', '64TALLINN10']
# ['328900******4997', 'door', 'together', 'SELVER', 'ISETEENI', 'lead', 'TARTU', 'LINN']
# ['17', '04', '1980', 'like', 'kaart...929592', 'great', 'SELVERI', 'ISET', 'TALLINN', 'EST', 'issue']
# ['(..5005)', 'myself', 'example', 'REMA', 'response', 'nation', 'character', 'out', 'old', 'fight', 'about', 'one', 'per', 'thus', 'konverteerimistasu', 'whatever', 'science', 'think', 'move', 'condition', 'already', 'behavior', 'management', 'choice']
# ['230764******1689', 'low', 'KAUBAMAJA', 'TARTU', 'leader', 'TARTUMAA', '', 'TAR']
# ['01', '10', '2009', 'age', 'kaart...223453', 'good', 'RIMI', 'painting', 'ISETE', 'TALLINN', 'EST', 'including']
# ['614921******6876', 'test', 'Prisma', 'Kristiine', 'Kesku', 'end', 'TALLINNA']
# ['(..0107)', 'late', 'paper', 'who', 'SELVER', 'onto', 'employee', 'TARTU', 'LINN', 'stand', 'crime']
# ['(..4984)', 'glass', 'nearly', 'today', 'Selver', 'street', 'Tallinn', 'scene', 'space']
# ['024896******6926', 'money', 'Prisma', 'eight', 'citizen', 'TALLINNA']
# ['(..6105)', 'its', 'walk', 'provide', 'SELVER', 'ISETEENIHAABNEEME', '', 'direction', 'TEE', 'change', 'power', 'VALD', 'ahead', 'instead']
# ['442106******7846', 'good', 'MAXIMA', 'NARVA', 'certain', 'place', 'behind', 'TARTU', 'LINN']
# ['(..6124)', 'seat', 'hope', '"GROSSI', 'TOIDUKAUBAD"', 'yes', 'TEE', 'include', 'LOO', 'owner', 'alone', 'exist']
# ['549703******0345', 'very', 'member', '"GROSSI', 'TOIDUKAUBADPIIRI', 'decide']
# ['26', '10', '2005', 'both', 'kaart...455285', 'EEDENI', 'MAKSIMARKET', 'TARTU', 'especially', 'think']
# ['(..3744)', 'successful', 'name', 'road', 'SELVERI', 'ISETEENINUKSNURME', 'TEE', 'answer', 'ahead', 'ago', 'share', 'can']
# ['20', '10', '1996', 'sea', 'kaart...640384', 'man', 'SELVER', 'TARTU', 'summer', 'item']
# ['15', '04', '2016', 'way', 'kaart...002379', 'building', 'KAUBAMAJAHAAPSA', 'data']
# ['403028******3553', 'doctor', 'southern', 'KONSUMNABALA', 'TEE', 'drop']
# ['(..7434)', 'forward', 'light', 'collection', 'SELVERI', 'site', 'TEE', 'network', 'TALLINN', 'man', 'reality']
# ['905621******2086', 'culture', 'opportunity', 'KONSUM', 'ISETEENIN', 'only', 'process', 'VALD']
# ['(..5400)', 'learn', 'live', 'EEDENI', 'MAKSIMARKET', 'point', 'TEE', 'enough', 'TARTU', 'LINN', 'ball', 'sign']
# ['038059******4436', 'town', 'Prisma', 'Rocca', 'al', 'Mare', 'relate', 'TALLINNA']
# ['874795******4330', 'represent', 'PAIDE', 'MAKSIMARKETRINGTEE', 'realize', 'determine']
# ['(..1160)', 'agent', 'fast', 'measure', 'RIMI', 'SM', 'ISETEENIE.VILDE', 'cost', 'include', 'minute', 'born']
# ['17', '05', '1990', 'man', 'kaart...510006', 'KAUBAMAJA', 'TALLINN', 'HARJUMAA', '', 'hand', 'natural']
# ['(..1465)', 'rock', 'that', 'herself', 'Selver', 'Tallinn', 'size', 'father']
# ['(..1968)', 'growth', 'good', 'ASTANGU', 'RIMI', 'ASTANGU', 'answer', 'TALLINN', 'energy', 'music']
# ['(..5508)', 'threat', 'risk', 'movement', 'SELVER', 'NARVA', 'yet', 'myself', 'TALLINN', 'bar', 'much']
# ['(..9202)', 'responsibility', 'short', 'A1000MARKET', 'medical', 'TALLINN', 'that', 'religious']
# ['19', '03', '1997', 'for', 'kaart...574182', 'live', 'KONSUM', 'ULENURME', 'ask', 'dinner']
# ['13', '01', '1988', 'feel', 'kaart...345256', 'RIMI', 'SOPRUSE', 'RIMI', 'HM', 'TALLINN', 'EST', 'recently']
# ['03', '11', '2009', 'be', 'kaart...357489', 'his', 'KONSUM', 'ISETEENIND', 'JURI', 'exist', 'yeah']
# ['20', '05', '1999', 'former', 'kaart...564944', 'probably', 'SELVERI', 'ISETEENI', 'TALLINN', 'EST', 'cover']
# ['(..0935)', 'surface', 'huge', 'performance', 'KONSUM', 'hear', 'executive', 'TARTUMAA', '', 'consider', 'must']
# ['109784******9822', 'paper', 'MAXIMA', 'coach', 'TEE', 'much', 'church', 'kitchen', 'TAL']
# ['464157******2078', 'official', 'GROSSI', 'TOIDUKAUBAD', 'back', 'religious']
# ['11', '01', '1986', 'sport', 'kaart...266732', 'RIMI', 'HIIU', 'RIMI', 'SM', 'toward', 'election', 'whose']
# ['(..8478)', 'in', 'history', 'RIMI', 'TELLISKIVI', 'RIMI', 'color', 'source', 'TALLINN', 'affect', 'contain']

# %%
# KUI VÕIMALIK SIIS TEKITAME remittanceInfost KUUPÄEVA
def getDate(rowList):
    try:
        day = rowList[0]
        month = rowList[1]
        year = rowList[2]
        if len(day) == 2 and len(month) == 2 and len(year) == 4:
            purchaseDate = date(int(year), int(month), int(day))
            formatted_date = purchaseDate.strftime('%d-%-m-%-Y')  # Format date as 'YYYY/M/D'
            return (True, formatted_date)
        else:
            return (False, False)
    except:
        return (False, False)
    
# KONTROLLIME KAS remittanceInfo SISALDAB MÄRGET, ET TEGU OLI ISETEENINDUSKASSAGA
def isSelfCheckout(elementFromRowAsList):
    if "ISETE" in elementFromRowAsList:
        return True
    else:
        return False    

# KÄIME LÄBI KÕIK DF READ NING EXTRACTIME SEALT KAARDINUMBRI JA/VÕI ISETEENINDUSKASSA MÄRGISTUSE JA/VÕI LINNA JA/VÕI KUUPÄEVA
# NING PANEME VASTAVAD ANDMED VASTAVATESSE TULPADESSE
for index, row in df.iterrows():
    rowRemittanceSeperatedList = re.split(r'[ ,/]', str(row["remittanceInfo"]))
    for i in range(0,len(rowRemittanceSeperatedList), 1):
        currentElement = str(rowRemittanceSeperatedList[i])
        if (currentElement != "" and currentElement != " " and currentElement != "-"):
            if (currentElement.count("*") > 1 or (currentElement[0] == "(" and currentElement[-1] == ")") or "kaart..." in currentElement):
                df.at[index, "cardNumber"] = currentElement
            if isSelfCheckout(currentElement):
                df.at[index, "selfCheckout"] = True
            if rowRemittanceSeperatedList[i].upper() in eestiLinnad:
                df.at[index, "city"] = currentElement.upper()
            dateCheck = getDate(rowRemittanceSeperatedList)
            if dateCheck[0] == True:
                df.at[index, "date"] = dateCheck[1]
            
# TO-DO
# A) cardNumber PUHTAKS, ET EI OLEKS kaart...983921 -> ....983921
#    IDEAALIS VÕIKSID KÕIK KAARDINUMBRID OLLA SAMA PIKAD
# B) -

# %%
df.head(40)
# Out:
#       id formattedDate merchantName  \
# 0   1269    24-07-2023    MAKSIMARK
# 1    319    14-06-2023         LIDL
# 3   1340    20-02-2023    MAKSIMARK
# 6    400    10-03-2023          ICA
# 7   1310    04-01-2023       MAXIMA
# 8    184    07-09-2023         RIMI
# 9   1292    09-01-2023       KONSUM
# 11   535    09-05-2023       SELVER
# 14   690    05-03-2023       KONSUM
# 17   322    01-07-2022       SELVER
# 18   525    26-08-2023         RIMI
# 21  1065    04-07-2023         RIMI
# 22  1853    02-08-2023         RIMI
# 23   348    28-04-2023       SELVER
# 26   868    17-08-2023       SELVER
# 27  1703    04-01-2023         RIMI
# 28  1781    25-03-2023    KAUBAMAJA
# 29  1817    12-07-2023         RIMI
# 31   369    11-04-2023       PRISMA
# 32   828    14-12-2022       SELVER
# 33  1209    15-01-2023       SELVER
# 34  1894    26-07-2022       PRISMA
# 35   522    07-07-2023       SELVER
# 36  1741    16-05-2023       MAXIMA
# 37    81    10-10-2022       GROSSI
# 38  1106    24-09-2023       GROSSI
# 39   377    28-07-2023    MAKSIMARK
# 40  1129    14-01-2023       SELVER
# 41   324    03-12-2022       SELVER
# 43  1859    15-02-2023    KAUBAMAJA
# 44   935    03-11-2022       KONSUM
# 46   195    26-03-2023       SELVER
# 48   479    01-01-2023       KONSUM
# 49  1707    25-05-2023    MAKSIMARK
# 50  1429    14-05-2023       PRISMA
# 51  1359    13-07-2023    MAKSIMARK
# 52  1361    11-06-2023         RIMI
# 53  1714    29-04-2022    KAUBAMAJA
# 54   119    01-11-2022       SELVER
# 56   897    06-06-2023         RIMI
#
#                                        remittanceInfo               value  \
# 0   567176******6366 toward information MAKSIMARKE...              -13.59
# 1   157466******5153 pay LIDL own TARTU sound behi...               -0.89
# 3   24/04/1997 resource kaart...878232 VILJANDI MA...               -12.9
# 6   551163******9009 which ICA AB/TARTU LOUNAKESK ...                -5.1
# 7   Kaart:411726******8003 human seven community a...              -17.35
# 8   576266******5911 return RIMI/TATARI RIMI ISETE...               -4.28
# 9   368085******4980 difficult act KONSUM ISETEENI...                   5
# 11  29/05/1985 traditional kaart...609240 huge SEL...              -21.86
# 14  146990******6058 light IHASTE KONSUM marriage ...               -1.29
# 17  (..1988) short simply stand SELVER ISETEENINSO...              -34.08
# 18  23/07/1973 half kaart...710047 RIMI/VILJANDI d...              -23.08
# 21  114088******7776 mind ICA paper RIMI H else TA...              -28.11
# 22  650344******0573 do ICA six RIMI road 64TALLINN10               -6.43
# 23  328900******4997 door together SELVER ISETEENI...               -9.07
# 26  17/04/1980 like kaart...929592 great SELVERI I...              -14.39
# 27  (..5005) myself example REMA response nation c...              -16.21
# 28  230764******1689 low KAUBAMAJA TARTU leader TA...               -6.68
# 29  01/10/2009 age kaart...223453 good RIMI painti...              -11.93
# 31  614921******6876 test Prisma Kristiine Kesku e...               -4.59
# 32  (..0107) late paper who SELVER onto employee T...              -11.56
# 33  (..4984) glass nearly today Selver street Tall...               -1.19
# 34  024896******6926 money Prisma eight citizen TA...                 -23
# 35  (..6105) its walk provide SELVER ISETEENIHAABN...               -4.28
# 36  442106******7846 good MAXIMA NARVA certain pla...               -12.1
# 37  (..6124) seat hope "GROSSI TOIDUKAUBAD" yes TE...               -2.09
# 38  549703******0345 very member "GROSSI TOIDUKAUB...              -28.54
# 39  26/10/2005 both kaart...455285 EEDENI MAKSIMAR...                -5.9
# 40  (..3744) successful name road SELVERI ISETEENI...  -7.769999999999999
# 41  20/10/1996 sea kaart...640384 man SELVER/TARTU...              -23.77
# 43  15/04/2016 way kaart...002379 building KAUBAMA...               -10.2
# 44  403028******3553 doctor southern KONSUMNABALA ...               -1.49
# 46  (..7434) forward light collection SELVERI site...              -20.67
# 48  905621******2086 culture opportunity KONSUM IS...              -27.83
# 49  (..5400) learn live EEDENI MAKSIMARKET point T...              -19.85
# 50  038059******4436 town Prisma Rocca al Mare rel...               -11.2
# 51  874795******4330 represent PAIDE MAKSIMARKETRI...                -2.6
# 52  (..1160) agent fast measure RIMI SM ISETEENIE....                  -8
# 53  17/05/1990 man kaart...510006 KAUBAMAJA TALLIN...               -1.79
# 54  (..1465) rock that herself Selver Tallinn size...              -17.83
# 56  (..1968) growth good ASTANGU RIMI ASTANGU answ...              -27.03
#
#                 cardNumber         city location selfCheckout        date
# 0         567176******6366  VILJANDIMAA     None         None        None
# 1         157466******5153     TARTUMAA     None         None        None
# 3           kaart...878232  VILJANDIMAA     None         None   24-4-1997
# 6         551163******9009     TARTUMAA     None         None        None
# 7   Kaart:411726******8003         None     None         None        None
# 8         576266******5911      TALLINN     None         True        None
# 9         368085******4980         None     None         True        None
# 11          kaart...609240      TALLINN     None         True   29-5-1985
# 14        146990******6058     TARTUMAA     None         None        None
# 17                (..1988)        TARTU     None         True        None
# 18          kaart...710047  VILJANDIMAA     None         None   23-7-1973
# 21        114088******7776      TALLINN     None         None        None
# 22        650344******0573         None     None         None        None
# 23        328900******4997        TARTU     None         True        None
# 26          kaart...929592      TALLINN     None         None   17-4-1980
# 27                (..5005)         None     None         None        None
# 28        230764******1689     TARTUMAA     None         None        None
# 29          kaart...223453      TALLINN     None         True  01-10-2009
# 31        614921******6876         None     None         None        None
# 32                (..0107)        TARTU     None         None        None
# 33                (..4984)      TALLINN     None         None        None
# 34        024896******6926         None     None         None        None
# 35                (..6105)         None     None         True        None
# 36        442106******7846        TARTU     None         None        None
# 37                (..6124)         None     None         None        None
# 38        549703******0345         None     None         None        None
# 39          kaart...455285        TARTU     None         None  26-10-2005
# 40                (..3744)         None     None         True        None
# 41          kaart...640384        TARTU     None         None  20-10-1996
# 43          kaart...002379         None     None         None   15-4-2016
# 44        403028******3553         None     None         None        None
# 46                (..7434)      TALLINN     None         None        None
# 48        905621******2086         None     None         True        None
# 49                (..5400)        TARTU     None         None        None
# 50        038059******4436         None     None         None        None
# 51        874795******4330        PAIDE     None         None        None
# 52                (..1160)         None     None         True        None
# 53          kaart...510006      TALLINN     None         None   17-5-1990
# 54                (..1465)      TALLINN     None         None        None
# 56                (..1968)      TALLINN     None         None        None

# %%
# EEMALDAME UUESTI "MAA" city LÕPUST KUNA NEID TEGELIKULT EI OLE VAJA. NEID OLI VAJA VAID TUVASTAMISEKS
# VA. PÕLTSAMAA SEST SELLE LINNA NIMI LÕPPEBKI "MAA"-GA JA SEE ON AINUKE SELLINE LINN EESTIS
for index, row in df.iterrows():
    if  row["city"] is not None and row["city"].endswith("MAA") and row["city"] != "PÕLTSAMAA":
        df.at[index, "city"] = row["city"][:-3]

# %%
df.head(50)
# Out:
#       id formattedDate merchantName  \
# 0   1269    24-07-2023    MAKSIMARK
# 1    319    14-06-2023         LIDL
# 3   1340    20-02-2023    MAKSIMARK
# 6    400    10-03-2023          ICA
# 7   1310    04-01-2023       MAXIMA
# 8    184    07-09-2023         RIMI
# 9   1292    09-01-2023       KONSUM
# 11   535    09-05-2023       SELVER
# 14   690    05-03-2023       KONSUM
# 17   322    01-07-2022       SELVER
# 18   525    26-08-2023         RIMI
# 21  1065    04-07-2023         RIMI
# 22  1853    02-08-2023         RIMI
# 23   348    28-04-2023       SELVER
# 26   868    17-08-2023       SELVER
# 27  1703    04-01-2023         RIMI
# 28  1781    25-03-2023    KAUBAMAJA
# 29  1817    12-07-2023         RIMI
# 31   369    11-04-2023       PRISMA
# 32   828    14-12-2022       SELVER
# 33  1209    15-01-2023       SELVER
# 34  1894    26-07-2022       PRISMA
# 35   522    07-07-2023       SELVER
# 36  1741    16-05-2023       MAXIMA
# 37    81    10-10-2022       GROSSI
# 38  1106    24-09-2023       GROSSI
# 39   377    28-07-2023    MAKSIMARK
# 40  1129    14-01-2023       SELVER
# 41   324    03-12-2022       SELVER
# 43  1859    15-02-2023    KAUBAMAJA
# 44   935    03-11-2022       KONSUM
# 46   195    26-03-2023       SELVER
# 48   479    01-01-2023       KONSUM
# 49  1707    25-05-2023    MAKSIMARK
# 50  1429    14-05-2023       PRISMA
# 51  1359    13-07-2023    MAKSIMARK
# 52  1361    11-06-2023         RIMI
# 53  1714    29-04-2022    KAUBAMAJA
# 54   119    01-11-2022       SELVER
# 56   897    06-06-2023         RIMI
# 57   829    16-04-2023       SELVER
# 58  1872    29-08-2023          ICA
# 59  1340    08-03-2023       KONSUM
# 60   790    25-10-2023         RIMI
# 61   474    14-05-2023       KONSUM
# 62    86    26-06-2023       SELVER
# 63   507    10-09-2023       KONSUM
# 65   197    08-08-2023       MAXIMA
# 67   415    03-08-2023       GROSSI
# 68   624    02-04-2022         RIMI
#
#                                        remittanceInfo               value  \
# 0   567176******6366 toward information MAKSIMARKE...              -13.59
# 1   157466******5153 pay LIDL own TARTU sound behi...               -0.89
# 3   24/04/1997 resource kaart...878232 VILJANDI MA...               -12.9
# 6   551163******9009 which ICA AB/TARTU LOUNAKESK ...                -5.1
# 7   Kaart:411726******8003 human seven community a...              -17.35
# 8   576266******5911 return RIMI/TATARI RIMI ISETE...               -4.28
# 9   368085******4980 difficult act KONSUM ISETEENI...                   5
# 11  29/05/1985 traditional kaart...609240 huge SEL...              -21.86
# 14  146990******6058 light IHASTE KONSUM marriage ...               -1.29
# 17  (..1988) short simply stand SELVER ISETEENINSO...              -34.08
# 18  23/07/1973 half kaart...710047 RIMI/VILJANDI d...              -23.08
# 21  114088******7776 mind ICA paper RIMI H else TA...              -28.11
# 22  650344******0573 do ICA six RIMI road 64TALLINN10               -6.43
# 23  328900******4997 door together SELVER ISETEENI...               -9.07
# 26  17/04/1980 like kaart...929592 great SELVERI I...              -14.39
# 27  (..5005) myself example REMA response nation c...              -16.21
# 28  230764******1689 low KAUBAMAJA TARTU leader TA...               -6.68
# 29  01/10/2009 age kaart...223453 good RIMI painti...              -11.93
# 31  614921******6876 test Prisma Kristiine Kesku e...               -4.59
# 32  (..0107) late paper who SELVER onto employee T...              -11.56
# 33  (..4984) glass nearly today Selver street Tall...               -1.19
# 34  024896******6926 money Prisma eight citizen TA...                 -23
# 35  (..6105) its walk provide SELVER ISETEENIHAABN...               -4.28
# 36  442106******7846 good MAXIMA NARVA certain pla...               -12.1
# 37  (..6124) seat hope "GROSSI TOIDUKAUBAD" yes TE...               -2.09
# 38  549703******0345 very member "GROSSI TOIDUKAUB...              -28.54
# 39  26/10/2005 both kaart...455285 EEDENI MAKSIMAR...                -5.9
# 40  (..3744) successful name road SELVERI ISETEENI...  -7.769999999999999
# 41  20/10/1996 sea kaart...640384 man SELVER/TARTU...              -23.77
# 43  15/04/2016 way kaart...002379 building KAUBAMA...               -10.2
# 44  403028******3553 doctor southern KONSUMNABALA ...               -1.49
# 46  (..7434) forward light collection SELVERI site...              -20.67
# 48  905621******2086 culture opportunity KONSUM IS...              -27.83
# 49  (..5400) learn live EEDENI MAKSIMARKET point T...              -19.85
# 50  038059******4436 town Prisma Rocca al Mare rel...               -11.2
# 51  874795******4330 represent PAIDE MAKSIMARKETRI...                -2.6
# 52  (..1160) agent fast measure RIMI SM ISETEENIE....                  -8
# 53  17/05/1990 man kaart...510006 KAUBAMAJA TALLIN...               -1.79
# 54  (..1465) rock that herself Selver Tallinn size...              -17.83
# 56  (..1968) growth good ASTANGU RIMI ASTANGU answ...              -27.03
# 57  (..5508) threat risk movement SELVER NARVA yet...               -9.53
# 58  (..9202) responsibility short A1000MARKET medi...              -20.79
# 59  19/03/1997 for kaart...574182 live KONSUM/ULEN...               -0.85
# 60  13/01/1988 feel kaart...345256 RIMI/SOPRUSE RI...               -6.79
# 61  03/11/2009 be kaart...357489 his KONSUM ISETEE...               -3.48
# 62  20/05/1999 former kaart...564944 probably SELV...                  -3
# 63  (..0935) surface huge performance KONSUM hear ...              -25.32
# 65  109784******9822 paper MAXIMA coach TEE much c...              -24.94
# 67  464157******2078 official GROSSI TOIDUKAUBAD b...              -21.22
# 68  11/01/1986 sport kaart...266732 RIMI/HIIU RIMI...               -2.44
#
#                 cardNumber      city location selfCheckout        date
# 0         567176******6366  VILJANDI     None         None        None
# 1         157466******5153     TARTU     None         None        None
# 3           kaart...878232  VILJANDI     None         None   24-4-1997
# 6         551163******9009     TARTU     None         None        None
# 7   Kaart:411726******8003      None     None         None        None
# 8         576266******5911   TALLINN     None         True        None
# 9         368085******4980      None     None         True        None
# 11          kaart...609240   TALLINN     None         True   29-5-1985
# 14        146990******6058     TARTU     None         None        None
# 17                (..1988)     TARTU     None         True        None
# 18          kaart...710047  VILJANDI     None         None   23-7-1973
# 21        114088******7776   TALLINN     None         None        None
# 22        650344******0573      None     None         None        None
# 23        328900******4997     TARTU     None         True        None
# 26          kaart...929592   TALLINN     None         None   17-4-1980
# 27                (..5005)      None     None         None        None
# 28        230764******1689     TARTU     None         None        None
# 29          kaart...223453   TALLINN     None         True  01-10-2009
# 31        614921******6876      None     None         None        None
# 32                (..0107)     TARTU     None         None        None
# 33                (..4984)   TALLINN     None         None        None
# 34        024896******6926      None     None         None        None
# 35                (..6105)      None     None         True        None
# 36        442106******7846     TARTU     None         None        None
# 37                (..6124)      None     None         None        None
# 38        549703******0345      None     None         None        None
# 39          kaart...455285     TARTU     None         None  26-10-2005
# 40                (..3744)      None     None         True        None
# 41          kaart...640384     TARTU     None         None  20-10-1996
# 43          kaart...002379      None     None         None   15-4-2016
# 44        403028******3553      None     None         None        None
# 46                (..7434)   TALLINN     None         None        None
# 48        905621******2086      None     None         True        None
# 49                (..5400)     TARTU     None         None        None
# 50        038059******4436      None     None         None        None
# 51        874795******4330     PAIDE     None         None        None
# 52                (..1160)      None     None         True        None
# 53          kaart...510006   TALLINN     None         None   17-5-1990
# 54                (..1465)   TALLINN     None         None        None
# 56                (..1968)   TALLINN     None         None        None
# 57                (..5508)   TALLINN     None         None        None
# 58                (..9202)   TALLINN     None         None        None
# 59          kaart...574182      None     None         None   19-3-1997
# 60          kaart...345256   TALLINN     None         None   13-1-1988
# 61          kaart...357489      None     None         True  03-11-2009
# 62          kaart...564944   TALLINN     None         True   20-5-1999
# 63                (..0935)     TARTU     None         None        None
# 65        109784******9822      None     None         None        None
# 67        464157******2078      None     None         None        None
# 68          kaart...266732      None     None         None   11-1-1986

# %%
#TÖÖTLEME KAUPLUSENIMED PUHTAMAKS
df['merchantName'] = df['merchantName'].replace('ICA', 'RIMI')
df['merchantName'] = df['merchantName'].replace('KONSUM', 'COOP')
df['merchantName'] = df['merchantName'].replace('MAKSIMARK', 'COOP')
df['merchantName'] = df['merchantName'].replace('MAKSIMARKET', 'COOP')

# %%
#VAATAME KÕIKI KESKMISI OSTUKORVIHINDU

df['value'] = pd.to_numeric(df['value'], errors='coerce')#VALUED NUMERIC TÜÜBIKS

average_values = df.groupby('merchantName')['value'].mean()#KESKMISED HINNAD POEKETI KAUPA
print(average_values)
# Out:
# merchantName
# A&O                -14.912647
# BLOOM               -1.750571
# COOP               -16.400579
# GROSSI             -15.540681
# KAUBAMAJA          -14.187237
# LIDL               -15.146752
# MAXIMA             -15.824094
# MEIE TOIDUKAUBAD   -24.935000
# PRISMA             -16.363286
# RIMI               -17.140231
# SELVER             -16.311279
# SIKUPILLI          -13.311818
# STOCKMANN          -15.647270
# Name: value, dtype: float64

# %%
#NÄITAME KÕIKI RIDU
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

#VAATAME, MIS VAHEMIKUS KUUPÄEVAD ON
earliest_date = df['formattedDate'].min()
latest_date = df['formattedDate'].max()

print("Earliest Date:", earliest_date)
print("Latest Date:", latest_date)

#TEEME KUUPÄEVA DATETIME FORMAADIKS
df['formattedDate'] = pd.to_datetime(df['formattedDate'], format='%d-%m-%Y')

#TEEME KUU COLUMNI
df['month'] = df['formattedDate'].dt.month

#ARVUTAME KESKMISED OSTUKORDVIHINNAD KUU JA POE KAUPA
average_values_by_month = df.groupby(['merchantName', 'month'])['value'].mean().reset_index()

print(average_values_by_month)

pd.set_option('display.max_rows', 60)
pd.set_option('display.max_columns', 60)
# Out:
# Earliest Date: 2021-11-30 00:00:00
# Latest Date: 2023-10-31 00:00:00
#          merchantName  month       value
# 0                 A&O      1  -13.511250
# 1                 A&O      2  -10.512222
# 2                 A&O      3  -13.577619
# 3                 A&O      4  -25.329333
# 4                 A&O      5  -18.408333
# 5                 A&O      6  -11.090625
# 6                 A&O      7  -12.602273
# 7                 A&O      8  -24.120455
# 8                 A&O      9  -11.869412
# 9                 A&O     10   -9.234167
# 10                A&O     11   -4.406667
# 11                A&O     12  -13.702000
# 12              BLOOM      1   -5.656667
# 13              BLOOM      2   -8.895000
# 14              BLOOM      3   -6.713333
# 15              BLOOM      4  -12.500000
# 16              BLOOM      5  -12.403333
# 17              BLOOM      6   -7.156000
# 18              BLOOM      7  -10.896000
# 19              BLOOM      8   -9.284000
# 20              BLOOM      9  115.250000
# 21              BLOOM     12   -7.450000
# 22               COOP      1  -15.749008
# 23               COOP      2  -16.389223
# 24               COOP      3  -17.286257
# 25               COOP      4  -17.436781
# 26               COOP      5  -14.930959
# 27               COOP      6  -16.657777
# 28               COOP      7  -17.300483
# 29               COOP      8  -14.836641
# 30               COOP      9  -16.614355
# 31               COOP     10  -16.399670
# 32               COOP     11  -16.858815
# 33               COOP     12  -16.973062
# 34             GROSSI      1  -13.119535
# 35             GROSSI      2  -15.933942
# 36             GROSSI      3  -16.860792
# 37             GROSSI      4  -14.654234
# 38             GROSSI      5  -15.951121
# 39             GROSSI      6  -13.960583
# 40             GROSSI      7  -17.849006
# 41             GROSSI      8  -16.058521
# 42             GROSSI      9  -13.672520
# 43             GROSSI     10  -15.365165
# 44             GROSSI     11  -14.092041
# 45             GROSSI     12  -17.764342
# 46          KAUBAMAJA      1  -11.823033
# 47          KAUBAMAJA      2  -17.204000
# 48          KAUBAMAJA      3  -16.017538
# 49          KAUBAMAJA      4  -16.112394
# 50          KAUBAMAJA      5  -14.325677
# 51          KAUBAMAJA      6  -14.257244
# 52          KAUBAMAJA      7  -11.616667
# 53          KAUBAMAJA      8  -13.240000
# 54          KAUBAMAJA      9  -13.725180
# 55          KAUBAMAJA     10  -11.969674
# 56          KAUBAMAJA     11  -14.623077
# 57          KAUBAMAJA     12  -16.790641
# 58               LIDL      1  -15.638571
# 59               LIDL      2  -12.540549
# 60               LIDL      3  -15.658777
# 61               LIDL      4  -17.048984
# 62               LIDL      5  -14.932770
# 63               LIDL      6  -13.102254
# 64               LIDL      7  -13.698426
# 65               LIDL      8  -17.663993
# 66               LIDL      9  -14.733919
# 67               LIDL     10  -16.561806
# 68               LIDL     11  -20.462099
# 69               LIDL     12  -10.610397
# 70             MAXIMA      1  -14.439105
# 71             MAXIMA      2  -14.879097
# 72             MAXIMA      3  -14.802533
# 73             MAXIMA      4  -16.620701
# 74             MAXIMA      5  -15.864004
# 75             MAXIMA      6  -16.143292
# 76             MAXIMA      7  -16.278085
# 77             MAXIMA      8  -16.450774
# 78             MAXIMA      9  -16.247010
# 79             MAXIMA     10  -16.620754
# 80             MAXIMA     11  -14.431070
# 81             MAXIMA     12  -15.750174
# 82   MEIE TOIDUKAUBAD      8  -24.935000
# 83             PRISMA      1  -18.191765
# 84             PRISMA      2  -16.439629
# 85             PRISMA      3  -15.088460
# 86             PRISMA      4  -15.458045
# 87             PRISMA      5  -19.083723
# 88             PRISMA      6  -17.648549
# 89             PRISMA      7  -16.131045
# 90             PRISMA      8  -14.638174
# 91             PRISMA      9  -16.361122
# 92             PRISMA     10  -14.677586
# 93             PRISMA     11  -15.838344
# 94             PRISMA     12  -17.150957
# 95               RIMI      1  -24.381074
# 96               RIMI      2  -17.177589
# 97               RIMI      3  -16.644566
# 98               RIMI      4  -16.561976
# 99               RIMI      5  -16.553599
# 100              RIMI      6  -16.767947
# 101              RIMI      7  -16.339671
# 102              RIMI      8  -16.228570
# 103              RIMI      9  -16.896612
# 104              RIMI     10  -16.628926
# 105              RIMI     11  -16.305763
# 106              RIMI     12  -16.984990
# 107            SELVER      1  -16.992467
# 108            SELVER      2  -17.456352
# 109            SELVER      3  -16.186866
# 110            SELVER      4  -16.697782
# 111            SELVER      5  -16.013333
# 112            SELVER      6  -15.666273
# 113            SELVER      7  -17.184404
# 114            SELVER      8  -15.882394
# 115            SELVER      9  -15.825358
# 116            SELVER     10  -15.820448
# 117            SELVER     11  -15.714160
# 118            SELVER     12  -16.095438
# 119         SIKUPILLI      1   -6.260000
# 120         SIKUPILLI      3   -1.890000
# 121         SIKUPILLI      4  -34.050000
# 122         SIKUPILLI      5   -3.080000
# 123         SIKUPILLI      6   -3.910000
# 124         SIKUPILLI      7  -13.060000
# 125         SIKUPILLI      9  -17.170000
# 126         SIKUPILLI     10  -14.525000
# 127         STOCKMANN      1  -11.748077
# 128         STOCKMANN      2   -7.744762
# 129         STOCKMANN      3  -13.279259
# 130         STOCKMANN      4  -17.179444
# 131         STOCKMANN      5  -17.903235
# 132         STOCKMANN      6  -15.754167
# 133         STOCKMANN      7  -19.662903
# 134         STOCKMANN      8  -15.366098
# 135         STOCKMANN      9  -17.263214
# 136         STOCKMANN     10  -18.439615
# 137         STOCKMANN     11  -13.894444
# 138         STOCKMANN     12  -15.475000

# %%
#PLOTIME KESKMISED VÄÄRTUSED
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

for merchant, group in average_values_by_month.groupby('merchantName'):
    plt.plot(group['month'], group['value'], label=merchant)

for merchant, group in average_values_by_month.groupby('merchantName'):
    plt.plot(group['month'], group['value'], label=merchant)


plt.title('Average Shopping Cart Values by Store and Month')
plt.xlabel('Month')
plt.ylabel('Average Value')
plt.legend(title='Merchant', loc='upper right')
plt.grid(True)
plt.show()

# %%
import pandas as pd

#TINGIMUS
filtered_df = df[(df['merchantName'] == 'BLOOM') & (df['formattedDate'].dt.month == 9)]

print(filtered_df)

#TODO Peaksime ühe veidralt suure kirje eemaldama, sest see rikub statistikat
# Out:
#          id formattedDate merchantName  \
# 74594   943    2023-09-02        BLOOM
# 93449  1410    2023-09-29        BLOOM
#
#                                           remittanceInfo  value  \
# 74594  (..0783) resource remember BLOOM magazine last...  -19.5
# 93449      076530******4613 person BLOOM billion TALLINN  250.0
#
#              cardNumber     city location selfCheckout  date  month
# 74594          (..0783)  TALLINN     None         None  None      9
# 93449  076530******4613  TALLINN     None         None  None      9
